# %%
"""
Python version: 3.12.7
Author: Zhen Chen, chen.zhen5526@gmail.com
Date: 2026/3/3 14:11
Description:


"""

import pandas as pd
import sys
import os
import statsmodels.formula.api as smf
from stargazer.stargazer import Stargazer

folder_address = ""
if sys.platform == "darwin":
    folder_address = "/Users/zhenchen/Library/CloudStorage/OneDrive-BrunelUniversityLondon/others/ezgi_data"
file_name = "JP_linear_regression_data.csv"
data_address = os.path.join(folder_address, file_name)

df_raw = pd.read_csv(data_address)

df1 = df_raw.dropna(subset="used_ai").copy()
df1["used_ai"] = df1["used_ai"].map({1.0: "No", 2.0: "Yes"})
df1["used_ai"] = df1["used_ai"].astype("category")
model1 = smf.ols(
    formula="trust_ai_6 ~ C(used_ai) + trust_ai_3 + mean_ai", data=df1
).fit()
print(model1.summary())

df2 = df_raw.dropna(subset="marital_status").copy()
df2["marital_status"] = df2["marital_status"].map(
    {
        1.0: "Civil Partnership",
        2.0: "Divorced",
        3.0: "Living as married",
        4.0: "Married",
        5.0: "Never married",
        6.0: "Separated after married",
        7.0: "Widowed",
    }
)
df2["marital_status"] = df2["marital_status"].astype("category")
model2 = smf.ols(
    formula="trust_ai_6 ~ C(marital_status) + trust_ai_3 + mean_ai", data=df2
).fit()
print(model2.summary())

df3 = df_raw.dropna(subset="working_status").copy()
df3["working_status"] = df3["working_status"].map(
    {
        1.0: "Full time>40",
        2.0: "Part time8-40",
        3.0: "Part time<8",
        4.0: "Full time student",
        5.0: "Retired",
        6.0: "Self-employed",
        7.0: "Unemployed",
        8.0: "Other",
    }
)
df3["working_status"] = df3["working_status"].astype("category")
model3 = smf.ols(
    formula="trust_ai_6 ~ C(working_status) + trust_ai_3 + mean_ai", data=df3
).fit()
print(model3.summary())

df4 = df_raw.dropna(subset="children_in_HH").copy()
df4["children_in_HH"] = df4["children_in_HH"].map(
    {
        1.0: "0",
        2.0: "1",
        3.0: "2",
        4.0: "3",
        5.0: "4",
        6.0: ">=5",
        7.0: "Don't know",
        8.0: "Prefer not to say",
    }
)
df4["children_in_HH"] = df4["children_in_HH"].astype("category")
model4 = smf.ols(
    formula="trust_ai_6 ~ C(children_in_HH) + trust_ai_3 + mean_ai", data=df4
).fit()
print(model4.summary())

df5 = df_raw.dropna(subset="household_size").copy()
df5["household_size"] = df5["household_size"].map(
    {
        1.0: "1",
        2.0: "2",
        3.0: "3",
        4.0: "4",
        5.0: "5",
        6.0: "6",
        7.0: "7",
        8.0: "8 or more",
        9.0: "Don't know",
        10.0: "Prefer not to say",
    }
)
df5["household_size"] = df5["household_size"].astype("category")
model5 = smf.ols(
    formula="trust_ai_6 ~ C(household_size) + trust_ai_3 + mean_ai", data=df5
).fit()
print(model5.summary())

df_raw.rename(columns={"urban/rural": "urban_rural"}, inplace=True)
df6 = df_raw.dropna(subset="urban_rural").copy()
df6["urban_rural"] = df6["urban_rural"].map(
    {
        1.0: "Tokyo or designated cities",
        2.0: "Other cities",
        6.0: "Towns and villages",
    }
)
df6["urban_rural"] = df6["urban_rural"].astype("category")
model6 = smf.ols(
    formula="trust_ai_6 ~ C(urban_rural) + trust_ai_3 + mean_ai", data=df6
).fit()
print(model6.summary())

from IPython.display import display, HTML

display(HTML("<style>.container { width:95% !important; }</style>"))

stargazer = Stargazer([model1, model2, model3, model4])
stargazer.custom_columns(["model1", "model2", "model3", "model4"], [1, 1, 1, 1])
stargazer.show_model_numbers(False)
stargazer.title("Regression Results")
stargazer.significance_levels([0.1, 0.05, 0.01])
stargazer
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             trust_ai_6   R-squared:                       0.270
# Model:                            OLS   Adj. R-squared:                  0.269
# Method:                 Least Squares   F-statistic:                     181.5
# Date:                Tue, 03 Mar 2026   Prob (F-statistic):          4.22e-100
# Time:                        16:15:05   Log-Likelihood:                -2265.3
# No. Observations:                1473   AIC:                             4539.
# Df Residuals:                    1469   BIC:                             4560.
# Df Model:                           3
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             1.6472      0.169      9.734      0.000       1.315       1.979
# C(used_ai)[T.Yes]     0.5955      0.066      9.022      0.000       0.466       0.725
# trust_ai_3            0.4931      0.024     20.402      0.000       0.446       0.541
# mean_ai               0.0733      0.029      2.490      0.013       0.016       0.131
# ==============================================================================
# Omnibus:                       27.173   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.820
# Skew:                          -0.121   Prob(JB):                     6.81e-11
# Kurtosis:                       3.839   Cond. No.                         35.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             trust_ai_6   R-squared:                       0.230
# Model:                            OLS   Adj. R-squared:                  0.226
# Method:                 Least Squares   F-statistic:                     52.94
# Date:                Tue, 03 Mar 2026   Prob (F-statistic):           2.53e-75
# Time:                        16:15:05   Log-Likelihood:                -2224.5
# No. Observations:                1425   AIC:                             4467.
# Df Residuals:                    1416   BIC:                             4514.
# Df Model:                           8
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                        1.4244      0.591      2.412      0.016       0.266       2.583
# C(marital_status)[T.Divorced]                    0.5249      0.593      0.886      0.376      -0.637       1.687
# C(marital_status)[T.Living as married]           0.4210      0.615      0.685      0.493      -0.785       1.627
# C(marital_status)[T.Married]                     0.5583      0.583      0.958      0.338      -0.585       1.702
# C(marital_status)[T.Never married]               0.7365      0.584      1.261      0.207      -0.409       1.882
# C(marital_status)[T.Separated after married]     0.3825      0.645      0.593      0.553      -0.882       1.647
# C(marital_status)[T.Widowed]                     0.3767      0.609      0.618      0.536      -0.818       1.572
# trust_ai_3                                       0.5067      0.025     19.961      0.000       0.457       0.557
# mean_ai                                          0.0189      0.032      0.597      0.551      -0.043       0.081
# ==============================================================================
# Omnibus:                       27.494   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               54.348
# Skew:                          -0.001   Prob(JB):                     1.58e-12
# Kurtosis:                       3.957   Cond. No.                         304.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             trust_ai_6   R-squared:                       0.251
# Model:                            OLS   Adj. R-squared:                  0.246
# Method:                 Least Squares   F-statistic:                     54.27
# Date:                Tue, 03 Mar 2026   Prob (F-statistic):           2.39e-85
# Time:                        16:15:05   Log-Likelihood:                -2280.3
# No. Observations:                1469   AIC:                             4581.
# Df Residuals:                    1459   BIC:                             4634.
# Df Model:                           9
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                              1.4934      0.266      5.620      0.000       0.972       2.015
# C(working_status)[T.Full time>40]      0.4870      0.214      2.272      0.023       0.066       0.908
# C(working_status)[T.Other]            -0.0442      0.297     -0.149      0.881      -0.626       0.538
# C(working_status)[T.Part time8-40]     0.1601      0.225      0.711      0.477      -0.281       0.602
# C(working_status)[T.Part time<8]       0.0343      0.270      0.127      0.899      -0.495       0.564
# C(working_status)[T.Retired]           0.0981      0.239      0.410      0.682      -0.371       0.567
# C(working_status)[T.Self-employed]     0.3327      0.240      1.385      0.166      -0.138       0.804
# C(working_status)[T.Unemployed]        0.0867      0.222      0.391      0.696      -0.348       0.521
# trust_ai_3                             0.5122      0.025     20.903      0.000       0.464       0.560
# mean_ai                                0.0644      0.030      2.121      0.034       0.005       0.124
# ==============================================================================
# Omnibus:                       27.086   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               51.503
# Skew:                          -0.051   Prob(JB):                     6.55e-12
# Kurtosis:                       3.912   Cond. No.                         123.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             trust_ai_6   R-squared:                       0.200
# Model:                            OLS   Adj. R-squared:                  0.184
# Method:                 Least Squares   F-statistic:                     12.75
# Date:                Tue, 03 Mar 2026   Prob (F-statistic):           1.24e-14
# Time:                        16:15:05   Log-Likelihood:                -566.86
# No. Observations:                 366   AIC:                             1150.
# Df Residuals:                     358   BIC:                             1181.
# Df Model:                           7
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                           1.6086      0.356      4.521      0.000       0.909       2.308
# C(children_in_HH)[T.1]             -0.0843      0.134     -0.628      0.531      -0.348       0.180
# C(children_in_HH)[T.2]             -0.1958      0.182     -1.078      0.282      -0.553       0.161
# C(children_in_HH)[T.3]             -0.0618      0.445     -0.139      0.890      -0.938       0.814
# C(children_in_HH)[T.4]             -0.3288      0.823     -0.400      0.690      -1.947       1.289
# C(children_in_HH)[T.Don't know]    -0.0516      0.523     -0.099      0.921      -1.081       0.978
# trust_ai_3                          0.4485      0.051      8.772      0.000       0.348       0.549
# mean_ai                             0.2055      0.064      3.235      0.001       0.081       0.330
# ==============================================================================
# Omnibus:                        7.399   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.025   Jarque-Bera (JB):               10.850
# Skew:                          -0.109   Prob(JB):                      0.00441
# Kurtosis:                       3.815   Cond. No.                         82.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             trust_ai_6   R-squared:                       0.227
# Model:                            OLS   Adj. R-squared:                  0.223
# Method:                 Least Squares   F-statistic:                     51.89
# Date:                Tue, 03 Mar 2026   Prob (F-statistic):           6.82e-74
# Time:                        16:15:05   Log-Likelihood:                -2216.9
# No. Observations:                1420   AIC:                             4452.
# Df Residuals:                    1411   BIC:                             4499.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  1.9866      0.188     10.541      0.000       1.617       2.356
# C(household_size)[T.2]    -0.0844      0.087     -0.972      0.331      -0.255       0.086
# C(household_size)[T.3]     0.0135      0.095      0.142      0.887      -0.173       0.200
# C(household_size)[T.4]     0.1456      0.103      1.412      0.158      -0.057       0.348
# C(household_size)[T.5]    -0.0757      0.136     -0.555      0.579      -0.343       0.192
# C(household_size)[T.6]     0.0440      0.233      0.189      0.850      -0.413       0.501
# C(household_size)[T.7]    -0.2551      0.415     -0.615      0.538      -1.068       0.558
# trust_ai_3                 0.5090      0.025     20.025      0.000       0.459       0.559
# mean_ai                    0.0251      0.031      0.798      0.425      -0.037       0.087
# ==============================================================================
# Omnibus:                       25.455   Durbin-Watson:                   2.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               48.209
# Skew:                          -0.036   Prob(JB):                     3.40e-11
# Kurtosis:                       3.900   Cond. No.                         81.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             trust_ai_6   R-squared:                       0.234
# Model:                            OLS   Adj. R-squared:                  0.232
# Method:                 Least Squares   F-statistic:                     111.7
# Date:                Tue, 03 Mar 2026   Prob (F-statistic):           3.62e-83
# Time:                        16:15:05   Log-Likelihood:                -2298.3
# No. Observations:                1470   AIC:                             4607.
# Df Residuals:                    1465   BIC:                             4633.
# Df Model:                           4
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                        1.8119      0.174     10.407      0.000       1.470       2.153
# C(urban_rural)[T.Tokyo or designated cities]     0.1205      0.069      1.748      0.081      -0.015       0.256
# C(urban_rural)[T.Towns and villages]             0.0031      0.096      0.032      0.974      -0.185       0.192
# trust_ai_3                                       0.5196      0.025     21.059      0.000       0.471       0.568
# mean_ai                                          0.0447      0.030      1.488      0.137      -0.014       0.104
# ==============================================================================
# Omnibus:                       27.406   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.366
# Skew:                          -0.018   Prob(JB):                     2.58e-12
# Kurtosis:                       3.933   Cond. No.                         35.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# <style>.container { width:95% !important; }</style>
# Regression Results<br><table style="text-align:center"><tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="4"><em>Dependent variable: trust_ai_6</em></td></tr><tr><td style="text-align:left"></td><tr><td></td><td colspan="1">model1</td><td colspan="1">model2</td><td colspan="1">model3</td><td colspan="1">model4</td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">C(children_in_HH)[T.1]</td><td></td><td></td><td></td><td>-0.084<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td></td><td>(0.134)</td></tr>
# <tr><td style="text-align:left">C(children_in_HH)[T.2]</td><td></td><td></td><td></td><td>-0.196<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td></td><td>(0.182)</td></tr>
# <tr><td style="text-align:left">C(children_in_HH)[T.3]</td><td></td><td></td><td></td><td>-0.062<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td></td><td>(0.445)</td></tr>
# <tr><td style="text-align:left">C(children_in_HH)[T.4]</td><td></td><td></td><td></td><td>-0.329<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td></td><td>(0.823)</td></tr>
# <tr><td style="text-align:left">C(children_in_HH)[T.Don't know]</td><td></td><td></td><td></td><td>-0.052<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td></td><td>(0.523)</td></tr>
# <tr><td style="text-align:left">C(marital_status)[T.Divorced]</td><td></td><td>0.525<sup></sup></td><td></td><td></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(0.593)</td><td></td><td></td></tr>
# <tr><td style="text-align:left">C(marital_status)[T.Living as married]</td><td></td><td>0.421<sup></sup></td><td></td><td></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(0.615)</td><td></td><td></td></tr>
# <tr><td style="text-align:left">C(marital_status)[T.Married]</td><td></td><td>0.558<sup></sup></td><td></td><td></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(0.583)</td><td></td><td></td></tr>
# <tr><td style="text-align:left">C(marital_status)[T.Never married]</td><td></td><td>0.737<sup></sup></td><td></td><td></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(0.584)</td><td></td><td></td></tr>
# <tr><td style="text-align:left">C(marital_status)[T.Separated after married]</td><td></td><td>0.383<sup></sup></td><td></td><td></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(0.645)</td><td></td><td></td></tr>
# <tr><td style="text-align:left">C(marital_status)[T.Widowed]</td><td></td><td>0.377<sup></sup></td><td></td><td></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(0.609)</td><td></td><td></td></tr>
# <tr><td style="text-align:left">C(used_ai)[T.Yes]</td><td>0.595<sup>***</sup></td><td></td><td></td><td></td></tr>
# <tr><td style="text-align:left"></td><td>(0.066)</td><td></td><td></td><td></td></tr>
# <tr><td style="text-align:left">C(working_status)[T.Full time>40]</td><td></td><td></td><td>0.487<sup>**</sup></td><td></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td>(0.214)</td><td></td></tr>
# <tr><td style="text-align:left">C(working_status)[T.Other]</td><td></td><td></td><td>-0.044<sup></sup></td><td></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td>(0.297)</td><td></td></tr>
# <tr><td style="text-align:left">C(working_status)[T.Part time8-40]</td><td></td><td></td><td>0.160<sup></sup></td><td></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td>(0.225)</td><td></td></tr>
# <tr><td style="text-align:left">C(working_status)[T.Part time<8]</td><td></td><td></td><td>0.034<sup></sup></td><td></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td>(0.270)</td><td></td></tr>
# <tr><td style="text-align:left">C(working_status)[T.Retired]</td><td></td><td></td><td>0.098<sup></sup></td><td></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td>(0.239)</td><td></td></tr>
# <tr><td style="text-align:left">C(working_status)[T.Self-employed]</td><td></td><td></td><td>0.333<sup></sup></td><td></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td>(0.240)</td><td></td></tr>
# <tr><td style="text-align:left">C(working_status)[T.Unemployed]</td><td></td><td></td><td>0.087<sup></sup></td><td></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td>(0.222)</td><td></td></tr>
# <tr><td style="text-align:left">Intercept</td><td>1.647<sup>***</sup></td><td>1.424<sup>**</sup></td><td>1.493<sup>***</sup></td><td>1.609<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.169)</td><td>(0.591)</td><td>(0.266)</td><td>(0.356)</td></tr>
# <tr><td style="text-align:left">mean_ai</td><td>0.073<sup>**</sup></td><td>0.019<sup></sup></td><td>0.064<sup>**</sup></td><td>0.205<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.029)</td><td>(0.032)</td><td>(0.030)</td><td>(0.064)</td></tr>
# <tr><td style="text-align:left">trust_ai_3</td><td>0.493<sup>***</sup></td><td>0.507<sup>***</sup></td><td>0.512<sup>***</sup></td><td>0.448<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.024)</td><td>(0.025)</td><td>(0.025)</td><td>(0.051)</td></tr>
#
# <td colspan="5" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align: left">Observations</td><td>1473</td><td>1425</td><td>1469</td><td>366</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.270</td><td>0.230</td><td>0.251</td><td>0.200</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.269</td><td>0.226</td><td>0.246</td><td>0.184</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>1.128 (df=1469)</td><td>1.156 (df=1416)</td><td>1.147 (df=1459)</td><td>1.151 (df=358)</td></tr><tr><td style="text-align: left">F Statistic</td><td>181.504<sup>***</sup> (df=3; 1469)</td><td>52.945<sup>***</sup> (df=8; 1416)</td><td>54.271<sup>***</sup> (df=9; 1459)</td><td>12.748<sup>***</sup> (df=7; 358)</td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td><td colspan="4" style="text-align: right"><sup>*</sup>p&lt;0.1; <sup>**</sup>p&lt;0.05; <sup>***</sup>p&lt;0.01</td></tr></table>
